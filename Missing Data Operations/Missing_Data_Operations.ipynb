# %%
import numpy as np
import pandas as pd

df=pd.read_csv("Melbourne.csv")
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  03-09-2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  03-12-2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  04-02-2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  04-02-2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  04-03-2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
print(df.shape)
print(df.info())
# Out:
# (23547, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23547 entries, 0 to 23546
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         23547 non-null  object
#  1   Address        23547 non-null  object
#  2   Rooms          23547 non-null  int64
#  3   Type           23547 non-null  object
#  4   Price          18396 non-null  float64
#  5   Method         23547 non-null  object
#  6   SellerG        23547 non-null  object
#  7   Date           23547 non-null  object
#  8   Distance       23546 non-null  float64
#  9   Postcode       23546 non-null  float64
#  10  Bedroom2       19066 non-null  float64
#  11  Bathroom       19063 non-null  float64
#  12  Car            18921 non-null  float64
#  13  Landsize       17410 non-null  float64
#  14  BuildingArea   10018 non-null  float64
#  15  YearBuilt      11540 non-null  float64
#  16  CouncilArea    15656 non-null  object
# ...

# %%
# checking whether data is null or not
df.isnull()
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False   True   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False   True   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 23542   False    False  False  False   True   False    False  False     False
# 23543   False    False  False  False   True   False    False  False     False
# 23544   False    False  False  False  False   False    False  False     False
# 23545   False    False  False  False  False   False    False  False     False
# 23546   False    False  False  False  False   False    False  False     False
#
# ...

# %% [markdown]
# ## Identifying missing values in Columns
# ### you can identify total missing values in a columns by using df.isnull().sum() method

# %%
# for each column check how many missing values are there
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %% [markdown]
# ## Identifying missing values in rows

# %%
# is there any missing value in a row
df.isnull().any(axis=1)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 23542     True
# 23543     True
# 23544     True
# 23545     True
# 23546     True
# Length: 23547, dtype: bool

# %%
# rows having all the missing values
df.isnull().all(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23542    False
# 23543    False
# 23544    False
# 23545    False
# 23546    False
# Length: 23547, dtype: bool

# %%
# sum of missing values in row
df.isnull().sum(axis=1)
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        0
#         ..
# 23542    2
# 23543    8
# 23544    4
# 23545    1
# 23546    2
# Length: 23547, dtype: int64

# %% [markdown]
# ## Treating missing values in a column

# %% [markdown]
# ## various methods for missing values are:-
# ### 1. Deletions* (Best prefer)
# ### 2.Imputation ---
#     2.1 Mean
#     2.2 Mode
#     2.3 Median

# %%
# summing up the missing values (column-wise)
# (missing values/total values)/100 and taking 2 digits after point 
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# BuildingArea     57.46
# YearBuilt        50.99
# CouncilArea      33.51
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
# removing 3 columns
df=df.drop('BuildingArea',axis=1)
df=df.drop('YearBuilt',axis=1)
df=df.drop('CouncilArea',axis=1)
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.88
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2         19.03
# Bathroom         19.04
# Car              19.65
# Landsize         26.06
# Lattitude        18.28
# Longtitude       18.28
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %% [markdown]
# ## Treating missing values in row

# %%
# rows having missing values more than 5
df[df.isnull().sum(axis=1)>5]
# Out:
#                   Suburb              Address  Rooms Type      Price Method  \
# 15            Abbotsford     217 Langridge St      3    h  1000000.0      S
# 16            Abbotsford      18a Mollison St      2    t   745000.0      S
# 19            Abbotsford  403/609 Victoria St      2    u   542000.0      S
# 21            Abbotsford    25/84 Trenerry Cr      2    u   760000.0     SP
# 22            Abbotsford    106/119 Turner St      1    u   481000.0     SP
# ...                  ...                  ...    ...  ...        ...    ...
# 23495  Templestowe Lower  1/207 Manningham Rd      2    u   550000.0     PI
# 23499          Thornbury      1/128 Dundas St      2    t   770000.0     PI
# 23502          Thornbury        111 Pender St      2    t   858000.0      S
# 23508             Toorak   21/1059 Malvern Rd      2    u   720000.0     VB
# 23531           Werribee         91 Latham St      4    h   540000.0     PI
#
# ...

# %%
# total rows having missing data in more than 5 columns
len(df[df.isnull().sum(axis=1)>5].index)
# Out:
# 4278

# %%
# percentage of missing data in row having more than 5 Nan values
(len(df[df.isnull().sum(axis=1)>5].index)/len(df.index))*100
# Out:
# 18.16791948018856

# %% [markdown]
# Thus we can remove these 18% data as they are having more missing values

# %%
# retaining the rows having atmost 5 missing values
df=df[df.isnull().sum(axis=1)<=5]

# looking at the summary again
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.71
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          1.05
# Bathroom          1.07
# Car               1.81
# Landsize          9.65
# Lattitude         0.13
# Longtitude        0.13
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
# removing price nan values
df=df[~np.isnan(df['Price'])]

# looking at the summary again
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         1.05
# Bathroom         1.07
# Car              1.76
# Landsize         9.83
# Lattitude        0.15
# Longtitude       0.15
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
# the amount of data we are left with
len(df.index)
# Out:
# 15086

# %%
df['Landsize'].describe()
# Out:
# count     13603.000000
# mean        558.116371
# std        3987.326586
# min           0.000000
# 25%         176.500000
# 50%         440.000000
# 75%         651.000000
# max      433014.000000
# Name: Landsize, dtype: float64

# %% [markdown]
# As it is having huge difference between min and max and 25,50,75% and max. SO if we impute then it will be a huge problem.
# So a better approach will be removing the corresponding rows from the Landsize.

# %%
# droping the missing row of Lansize
df=df[~np.isnan(df['Landsize'])]

# looking at the summary again
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.16
# Longtitude       0.16
# Regionname       0.00
# Propertycount    0.00
# dtype: float64

# %%
# left data
len(df.index)
# Out:
# 13603

# %%
df[np.isnan(df['Lattitude'])]
# Out:
#                    Suburb                Address  Rooms Type      Price  \
# 2572              Burwood           23 Monica St      3    h   990000.0
# 3257         Clifton Hill  3/268 Alexandra Pde E      1    u   363000.0
# 4485            Footscray          483 Barkly St      3    t   781000.0
# 5170         Hampton East           7 Seafoam St      4    t  1185000.0
# 10745  Williamstown North         4/9 Adeline St      1    u   355000.0
# 13223           Melbourne   1913/228 Abeckett St      3    u  1175000.0
# 14008            Brooklyn          9 Richards Ct      3    h   750000.0
# 14132     North Melbourne   13/201 Abbotsford St      2    t   755000.0
# 14139      Oakleigh South            4 Druitt St      4    h  1205500.0
# 14142      Oakleigh South        298 Warrigal Rd      3    h   799999.0
# 14143      Oakleigh South            11 Yarra Ct      5    h  1200000.0
# 14976            Essendon        9 Washington St      3    h  1520000.0
# ...

# %%
df.loc[:,['Lattitude','Longtitude']].describe()
# Out:
#           Lattitude    Longtitude
# count  13581.000000  13581.000000
# mean     -37.809204    144.995221
# std        0.079257      0.103913
# min      -38.182550    144.431810
# 25%      -37.856820    144.929600
# 50%      -37.802360    145.000100
# 75%      -37.756400    145.058320
# max      -37.408530    145.526350

# %%
# imputing Lattitude and Long. values by mean vales
df.loc[np.isnan(df['Lattitude']),['Lattitude']] = df['Lattitude'].mean()
df.loc[np.isnan(df['Longtitude']),['Longtitude']] = df['Longtitude'].mean()

# looking at the summary again
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Suburb           0.00
# Address          0.00
# Rooms            0.00
# Type             0.00
# Price            0.00
# Method           0.00
# SellerG          0.00
# Date             0.00
# Distance         0.00
# Postcode         0.00
# Bedroom2         0.00
# Bathroom         0.01
# Car              0.46
# Landsize         0.00
# Lattitude        0.00
# Longtitude       0.00
# Regionname       0.00
# Propertycount    0.00
# dtype: float64
